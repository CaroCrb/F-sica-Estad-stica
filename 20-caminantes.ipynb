# %%
import numpy as np
from numpy import random as r
import matplotlib.pyplot as plt

# %%
def caminante(N):
    pasos=r.choice([-1,0,1],N) #Elegimos el -1,0,1 como los valores que pueden tomar los pasos
    caminante=np.cumsum(pasos) #Realizamos la suma de los pasos
    
    return(caminante)

# %%
#Aplicamos la función a los 20 caminantes que necesitamos
cam1=caminante(30)
cam2=caminante(30)
cam3=caminante(30)
cam4=caminante(30)
cam5=caminante(30)
cam6=caminante(30)
cam7=caminante(30)
cam8=caminante(30)
cam9=caminante(30)
cam10=caminante(30)
cam11=caminante(30)
cam12=caminante(30)
cam13=caminante(30)
cam14=caminante(30)
cam15=caminante(30)
cam16=caminante(30)
cam17=caminante(30)
cam18=caminante(30)
cam19=caminante(30)
cam20=caminante(30)

# %%
def f1(x):
    return (2*x/3)**(1/2)
def f2(x):
    return -(2*x/3)**(1/2)
x=range(0,30)

# %%
#Graficamos todos los caminantes en la misma gráfica
#k y r representan los colores de las líneas de la gráfica
plt.plot(cam1,'k')
plt.plot(cam2,'k')
plt.plot(cam3,'k')
plt.plot(cam4,'k')
plt.plot(cam5,'k')
plt.plot(cam6,'k')
plt.plot(cam7,'k')
plt.plot(cam8,'k')
plt.plot(cam9,'k')
plt.plot(cam10,'k')
plt.plot(cam11,'k')
plt.plot(cam12,'k')
plt.plot(cam13,'k')
plt.plot(cam14,'k')
plt.plot(cam15,'k')
plt.plot(cam16,'k')
plt.plot(cam17,'k')
plt.plot(cam18,'k')
plt.plot(cam19,'k')
plt.plot(cam20,'k')
plt.plot(x,[f1(i) for i in x],'r')
plt.plot(x,[f2(i) for i in x],'r')
plt.title("20 Caminantes Aleatorios")
plt.xlabel("Número de pasos")
plt.ylabel("Posición")

plt.figure(figsize=(15,6))
